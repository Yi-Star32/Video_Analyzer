# %% [markdown]
# # Alignment pipeline (debug, fixed)
#
# Robust discovery of episodes_audio by scanning upward through parent directories. Prints cwd, chosen episodes dir and found .webm files.

# %%
# !git clone https://github.com/Yi-Star32/Video_Analyzer.git
# Out:
# Cloning into 'Video_Analyzer'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 43 (delta 6), reused 29 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 57.42 KiB | 3.83 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# %cd Video_Analyzer
# Out:
# /content/Video_Analyzer

# %%
# !pip install -r requirements.txt
# Out:
# Collecting absl-py==2.4.0 (from -r requirements.txt (line 1))
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: annotated-doc==0.0.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.0.4)
# Requirement already satisfied: antlr4-python3-runtime==4.9.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (4.9.3)
# Requirement already satisfied: anyio==4.13.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (4.13.0)
# Collecting asttokens==3.0.1 (from -r requirements.txt (line 5))
#   Using cached asttokens-3.0.1-py3-none-any.whl.metadata (4.9 kB)
# ERROR: Ignored the following versions that require a different python version: 0.1.0 Requires-Python >=3.13; 0.2.0 Requires-Python >=3.13; 0.2.1 Requires-Python >=3.13; 0.2.2 Requires-Python >=3.13
# ERROR: Could not find a version that satisfies the requirement audioop-lts==0.2.2 (from versions: none)
# ERROR: No matching distribution found for audioop-lts==0.2.2

# %%
# !pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.14.2)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (26.2)

# %%
# !pip install git+https://github.com/m-bain/whisperx.git
# Out:
# Collecting git+https://github.com/m-bain/whisperx.git
#   Cloning https://github.com/m-bain/whisperx.git to /tmp/pip-req-build-xkwvox3y
#   Running command git clone --filter=blob:none --quiet https://github.com/m-bain/whisperx.git /tmp/pip-req-build-xkwvox3y
#   Resolved https://github.com/m-bain/whisperx.git to commit 3ccc17b8de34f305300f8a3fd3c9f76ba820c0d0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: ctranslate2>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from whisperx==3.8.6) (4.7.2)
# Requirement already satisfied: faster-whisper>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from whisperx==3.8.6) (1.2.1)
# Requirement already satisfied: nltk>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from whisperx==3.8.6) (3.9.1)
# Collecting numpy>=2.1.0 (from whisperx==3.8.6)
#   Using cached numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: omegaconf>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from whisperx==3.8.6) (2.3.0)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.12/dist-packages (from whisperx==3.8.6) (3.0.3)
# Requirement already satisfied: pyannote-audio>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from whisperx==3.8.6) (4.0.4)
# Requirement already satisfied: huggingface-hub<1.0.0 in /usr/local/lib/python3.12/dist-packages (from whisperx==3.8.6) (0.36.2)
# Requirement already satisfied: torch~=2.8.0 in /usr/local/lib/python3.12/dist-packages (from whisperx==3.8.6) (2.8.0)
# Requirement already satisfied: torchaudio~=2.8.0 in /usr/local/lib/python3.12/dist-packages (from whisperx==3.8.6) (2.8.0)
# Requirement already satisfied: torchvision~=0.23.0 in /usr/local/lib/python3.12/dist-packages (from whisperx==3.8.6) (0.23.0)
# Requirement already satisfied: torchcodec<0.8.0,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from whisperx==3.8.6) (0.7.0)
# Requirement already satisfied: transformers>=4.48.0 in /usr/local/lib/python3.12/dist-packages (from whisperx==3.8.6) (4.57.6)
# Requirement already satisfied: triton>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from whisperx==3.8.6) (3.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from ctranslate2>=4.5.0->whisperx==3.8.6) (75.2.0)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.12/dist-packages (from ctranslate2>=4.5.0->whisperx==3.8.6) (6.0.3)
# Requirement already satisfied: tokenizers<1,>=0.13 in /usr/local/lib/python3.12/dist-packages (from faster-whisper>=1.2.0->whisperx==3.8.6) (0.22.2)
# Requirement already satisfied: onnxruntime<2,>=1.14 in /usr/local/lib/python3.12/dist-packages (from faster-whisper>=1.2.0->whisperx==3.8.6) (1.26.0)
# Requirement already satisfied: av>=11 in /usr/local/lib/python3.12/dist-packages (from faster-whisper>=1.2.0->whisperx==3.8.6) (17.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from faster-whisper>=1.2.0->whisperx==3.8.6) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0->whisperx==3.8.6) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0->whisperx==3.8.6) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0->whisperx==3.8.6) (1.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0->whisperx==3.8.6) (26.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0->whisperx==3.8.6) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0->whisperx==3.8.6) (4.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9.1->whisperx==3.8.6) (8.4.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9.1->whisperx==3.8.6) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9.1->whisperx==3.8.6) (2025.11.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf>=2.3.0->whisperx==3.8.6) (4.9.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->whisperx==3.8.6) (2.9.0.post0)
# Requirement already satisfied: asteroid-filterbanks>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (0.4.0)
# Requirement already satisfied: einops>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (0.8.2)
# Requirement already satisfied: lightning>=2.4 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (2.6.5)
# Requirement already satisfied: matplotlib>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (3.10.0)
# Requirement already satisfied: opentelemetry-api>=1.34.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (1.42.1)
# Requirement already satisfied: opentelemetry-exporter-otlp>=1.34.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (1.42.1)
# Requirement already satisfied: opentelemetry-sdk>=1.34.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (1.42.1)
# Requirement already satisfied: pyannote-core>=6.0.1 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (6.0.1)
# Requirement already satisfied: pyannote-database>=6.1.1 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (6.1.1)
# Requirement already satisfied: pyannote-metrics>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (4.1)
# Requirement already satisfied: pyannote-pipeline>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (4.0.0)
# Requirement already satisfied: pyannoteai-sdk>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (0.4.0)
# Requirement already satisfied: pytorch-metric-learning>=2.8.1 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (2.9.0)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (13.9.4)
# Requirement already satisfied: safetensors>=0.5.2 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (0.7.0)
# Requirement already satisfied: torch-audiomentations>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (0.12.0)
# Requirement already satisfied: torchmetrics>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from pyannote-audio>=4.0.0->whisperx==3.8.6) (1.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch~=2.8.0->whisperx==3.8.6) (1.13.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision~=0.23.0->whisperx==3.8.6) (11.3.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.4->pyannote-audio>=4.0.0->whisperx==3.8.6) (0.15.3)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning>=2.4->pyannote-audio>=4.0.0->whisperx==3.8.6) (2.6.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (3.3.2)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper>=1.2.0->whisperx==3.8.6) (25.12.19)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper>=1.2.0->whisperx==3.8.6) (5.29.6)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.42.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp>=1.34.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.42.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.42.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp>=1.34.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.42.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.42.1->opentelemetry-exporter-otlp>=1.34.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.75.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.42.1->opentelemetry-exporter-otlp>=1.34.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.80.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.42.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.42.1->opentelemetry-exporter-otlp>=1.34.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.42.1)
# Requirement already satisfied: opentelemetry-proto==1.42.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.42.1->opentelemetry-exporter-otlp>=1.34.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.42.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.34.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (0.63b1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-core>=6.0.1->pyannote-audio>=4.0.0->whisperx==3.8.6) (2.4.0)
# Requirement already satisfied: scikit-learn>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from pyannote-metrics>=4.0.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.6.1)
# Requirement already satisfied: scipy>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from pyannote-metrics>=4.0.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.16.3)
# Requirement already satisfied: optuna>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from pyannote-pipeline>=4.0.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (4.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->whisperx==3.8.6) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0->whisperx==3.8.6) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0->whisperx==3.8.6) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0->whisperx==3.8.6) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0->whisperx==3.8.6) (2026.5.20)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->pyannote-audio>=4.0.0->whisperx==3.8.6) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->pyannote-audio>=4.0.0->whisperx==3.8.6) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch~=2.8.0->whisperx==3.8.6) (1.3.0)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from torch-audiomentations>=0.12.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (0.2.7)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from torch-audiomentations>=0.12.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch~=2.8.0->whisperx==3.8.6) (3.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning>=2.4->pyannote-audio>=4.0.0->whisperx==3.8.6) (3.13.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->pyannote-audio>=4.0.0->whisperx==3.8.6) (0.1.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=4.2.0->pyannote-pipeline>=4.0.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.18.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna>=4.2.0->pyannote-pipeline>=4.0.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=4.2.0->pyannote-pipeline>=4.0.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (2.0.49)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.1->pyannote-metrics>=4.0.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (3.6.0)
# Requirement already satisfied: primePy>=1.3 in /usr/local/lib/python3.12/dist-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.12.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.4->pyannote-audio>=4.0.0->whisperx==3.8.6) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.4->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.4->pyannote-audio>=4.0.0->whisperx==3.8.6) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.4->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.4->pyannote-audio>=4.0.0->whisperx==3.8.6) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.4->pyannote-audio>=4.0.0->whisperx==3.8.6) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.4->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.24.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=4.2.0->pyannote-pipeline>=4.0.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (1.3.12)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=4.2.0->pyannote-pipeline>=4.0.0->pyannote-audio>=4.0.0->whisperx==3.8.6) (3.5.1)
# Using cached numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.3 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.3 which is incompatible.
# db-dtypes 1.6.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.3 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.6 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.3 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.3 which is incompatible.
# Successfully installed numpy-2.4.6

# %%
# !pip install "numpy<2.0.0"
# Out:
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.12/dist-packages (1.26.4)

# %%
from audio_matcher import alignment, chunking, embedding, index, io, phonemes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
from pathlib import Path
import warnings
from tqdm import TqdmWarning

# 1. Zorg dat Python de 'audio_matcher' map kan vinden
# (Pas dit pad aan als je Video_Analyzer map ergens anders staat, bv. in je Drive)
project_path = "/content/Video_Analyzer"
if project_path not in sys.path:
    sys.path.append(project_path)

# 2. Onderdruk specifieke tqdm waarschuwingen
warnings.filterwarnings("ignore", category=TqdmWarning)

# 3. Importeer de audio_matcher onderdelen
from audio_matcher.embedding import AudioEmbeddingPipeline
from audio_matcher.phonemes import PhonemeAligner
from audio_matcher.alignment import build_phoneme_index_from_episodes, run_phoneme_pipeline
from audio_matcher.io import export_audio

# 4. Stel het absolute pad in naar je song (zorg dat je Drive gekoppeld is!)
SONG_PATH = Path("/content/drive/MyDrive/projecten/Video_Analyzer_data/output/separated/htdemucs/audio/vocals.wav")

# 5. Check direct of het bestand bestaat
if SONG_PATH.exists():
    print("🎉 Alles succesvol geïmporteerd en het audiobestand is gevonden!")
else:
    print("⚠️ Imports geslaagd, maar het bestand 'vocals.wav' werd niet gevonden op dit pad. Check of je Drive is gekoppeld.")
# Out:
# 🎉 Alles succesvol geïmporteerd en het audiobestand is gevonden!

# %%
from pathlib import Path

# Pas dit aan naar de exacte plek van je projectmap
# Als hij in je Drive staat: Path("/content/drive/MyDrive/.../Video_Analyzer")
repo_root = Path("/content/drive/MyDrive/projecten/Video_Analyzer_data")

print('notebook cwd ingesteld op =', repo_root)
EPISODES_DIR = None

# Vanaf hier blijft je eigen code exact hetzelfde:
for p in [repo_root] + list(repo_root.parents):
    candidates = [
        p / 'data' / 'episodes_audio',
        p / 'audio_matcher' / 'data' / 'episodes_audio',
        p / 'episodes_audio',
    ]
    for c in candidates:
        if c.exists():
            EPISODES_DIR = c
            break
    if EPISODES_DIR is not None:
        break

if EPISODES_DIR is None:
    EPISODES_DIR = repo_root / 'data' / 'episodes_audio'

print('EPISODES_DIR chosen:', EPISODES_DIR)
if not EPISODES_DIR.exists():
    print('EPISODES_DIR does not exist:', EPISODES_DIR)
    files = []
else:
    files = sorted(EPISODES_DIR.rglob('audio.wav'))
    print(f'Found {len(files)} audio.wav files under {EPISODES_DIR}')
    for f in files:
        print('-', f)
# Out:
# notebook cwd ingesteld op = /content/drive/MyDrive/projecten/Video_Analyzer_data
# EPISODES_DIR chosen: /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio
# Found 30 audio.wav files under /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/1TlOcjJodHw/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/326R_Lhua5w/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/3l1lSNQxJA0/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/6uNYmqvF24k/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/9IymXcXl4fk/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/9aLD8SGoPIc/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/9wAKxOavTnw/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/COr4zRFX0Gw/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/Cd-3_QOIjgU/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/JhhupHQlal8/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/ObtS79k2NM4/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/PEUL-1_zGWI/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/R-GNznqs7cI/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/RcBw50wD9_o/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/T23nJU-KwZo/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/TYhdezzyqPo/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/XwpbJK-WE8Q/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/_LhB0LIQlQ0/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/boY4QaYhBeM/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/dJgDmrra3kM/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/f8mWMqLO88A/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/h6LFdBPjbf4/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/hrANeOomxRw/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/iaxkOJZxzQM/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/lKggkmrv7q4/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/mRR7mbV0u4U/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/nfpsYGAGzF0/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/rcA8dMGOMCw/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/rrQmjrZedac/audio.wav
# - /content/drive/MyDrive/projecten/Video_Analyzer_data/data/episodes_audio/z3hMX65Khtg/audio.wav

# %%
import gc
import torch
import numpy as np

# Automatisch GPU kiezen als die er is, anders veilig terugvallen op CPU
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"🚀 WhisperX gaat draaien op: {device.upper()}")

pipeline = AudioEmbeddingPipeline()

# Hier vullen we de 'device' variabele in
aligner = PhonemeAligner(device=device, whisper_model='base')

# Je lijst met bestanden uit de vorige cell
files = files

# Start het bouwen van de index
pindex = build_phoneme_index_from_episodes(files, aligner, pipeline)

print("🎉 De phoneme index is succesvol opgebouwd!")
# Out:
# 🚀 WhisperX gaat draaien op: CUDA
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/transformers/configuration_utils.py:335: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# Building phoneme index from episodes:   0%|          | 0/30 [00:00<?, ?it/s]
# 2026-06-02 11:47:31 - whisperx.asr - INFO - No language specified, language will be detected for each audio file (increases inference time)
# 2026-06-02 11:47:31 - whisperx.vads.pyannote - INFO - Performing voice activity detection using Pyannote...
# INFO: Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.6.5. To apply the upgrade to your files permanently, run `python -m lightning.pytorch.utilities.upgrade_checkpoint ../../usr/local/lib/python3.12/dist-packages/whisperx/assets/pytorch_model.bin`
# INFO:lightning.pytorch.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.6.5. To apply the upgrade to your files permanently, run `python -m lightning.pytorch.utilities.upgrade_checkpoint ../../usr/local/lib/python3.12/dist-packages/whisperx/assets/pytorch_model.bin`
# /usr/local/lib/python3.12/dist-packages/pyannote/audio/utils/reproducibility.py:74: ReproducibilityWarning: TensorFloat-32 (TF32) has been disabled as it might lead to reproducibility issues and lower accuracy.
# It can be re-enabled by calling
#    >>> import torch
#    >>> torch.backends.cuda.matmul.allow_tf32 = True
#    >>> torch.backends.cudnn.allow_tf32 = True
# See https://github.com/pyannote/pyannote-audio/issues/1370 for more details.
#
#   warnings.warn(
# 2026-06-02 11:47:37 - whisperx.asr - INFO - Detected language: en (0.81) in first 30s of audio
#   [audio.wav] 8994 phonemes
# Building phoneme index from episodes:   0%|          | 0/30 [05:56<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_15510/529360220.py in <cell line: 0>()
#      16
#      17 # Start het bouwen van de index
# ---> 18 pindex = build_phoneme_index_from_episodes(files, aligner, pipeline)
#      19
#      20 print("🎉 De phoneme index is succesvol opgebouwd!")
#
# /content/Video_Analyzer/audio_matcher/alignment.py in build_phoneme_index_from_episodes(file_paths, aligner, embedder)
#     204                         continue
#     205                     try:
# --> 206                         emb = embedder.embed_audio(seg, sr=sr, normalize=True)
#     207                     except Exception:
#     208                         continue
#
# /content/Video_Analyzer/audio_matcher/embedding.py in embed_audio(self, audio, sr, normalize)
#      19         with torch.no_grad():
#      20             hidden = self.model(input_values).last_hidden_state
# ---> 21             emb = hidden.mean(dim=1).cpu().numpy()
#      22         if normalize:
#      23             emb = self._l2_normalize(emb)
#
# KeyboardInterrupt:

# %%
# final: run phoneme pipeline on chosen song and export
if not files:
    print('No reference files found, skipping pipeline')
else:
    final_audio = run_phoneme_pipeline(SONG_PATH, None, aligner, pipeline, pindex=pindex)
    print(f"output_ms: {len(final_audio)}")
    export_audio(final_audio, '/content/drive/MyDrive/projecten/Video_Analyzer_data/output/aligned_output_colab1.wav')
    print('Wrote aligned_output.wav')
